# %%
#Program to Generate a Vandermonde matrix.
import numpy as np
input_array=np.array([1,2,3,4,5])
vander_array=np.vander(input_array,N=4,increasing=True)
vander_array
# Out:
# array([[  1,   1,   1,   1],
#        [  1,   2,   4,   8],
#        [  1,   3,   9,  27],
#        [  1,   4,  16,  64],
#        [  1,   5,  25, 125]])

# %%
#Program to find the  moving average in an array over a window,using function
import numpy as np

avg_array=[]
def moving_average_function(inputlist=[],*args):
    try:
        for i in range(0,len(inputlist)):
            sum=0
            empty_list=[]
        
            for j in range(i,i+3):
                empty_list.append(inputlist[j])
                sum=sum+inputlist[j]
                avg=sum//4
            
             
            print(" Moving Average of Elements" +str(empty_list)+"are" ,avg)
            avg_array.append(avg)
        
        
        
    except:
        print("Array Index Out Of BoundsException")
    finally:
        print("The Moving average sequence has",str(len(avg_array))+"values")
        print("Done")
        
inputlist=np.array([3, 5, 7, 2, 8, 10, 11, 65, 72, 81, 99, 100, 150])
moving_average_function(inputlist)
# Out:
#  Moving Average of Elements[3, 5, 7]are 3
#  Moving Average of Elements[5, 7, 2]are 3
#  Moving Average of Elements[7, 2, 8]are 4
#  Moving Average of Elements[2, 8, 10]are 5
#  Moving Average of Elements[8, 10, 11]are 7
#  Moving Average of Elements[10, 11, 65]are 21
#  Moving Average of Elements[11, 65, 72]are 37
#  Moving Average of Elements[65, 72, 81]are 54
#  Moving Average of Elements[72, 81, 99]are 63
#  Moving Average of Elements[81, 99, 100]are 70
#  Moving Average of Elements[99, 100, 150]are 87
# Array Index Out Of BoundsException
# The Moving average sequence has 11values
# Done

# %%
#Program to count-distance-to-the-previous-zero
import pandas as pd
inputarray=[7, 2, 0, 3, 4, 2, 5, 0, 3, 4]
position_of_zero=None
output_array=[]
for i in range(0,len(inputarray)):
    if input[i] == 0:
        output_array.append(inputarray[i])
        position_of_zero=i
    else:
        if  position_of_zero== None:
            output_array.append(i+1)
        else:    
            output_array.append(i- position_of_zero)
df=pd.DataFrame({"X":inputarray,
                  "Y":output_array})
print(df)
# Out:
#    X  Y
# 0  7  1
# 1  2  2
# 2  0  0
# 3  3  1
# 4  4  2
# 5  2  3
# 6  5  4
# 7  0  0
# 8  3  1
# 9  4  2

# %%
#Create a DatetimeIndex that contains each business day of 2015 and use it to index a Series of random numbers.
import pandas as pd
import numpy as np

def create_calendar(start='2015-1-1',end='2015-12-31'):
    random_numbers=np.random.randint(low=1,high=365,size=365)
    df =pd.DataFrame({"Date":pd.bdate_range(start,end)})
    lengthdf = len(df)
    df["random_index"] = np.random.randint(low =1, high = 100, size=lengthdf)
    df["month"]=df.Date.dt.month
    df["date"]=df.Date.dt.day
    df["day"]=df.Date.dt.weekday_name
   
    return df

create_calendar().head(100)
# Out:
#          Date  random_index  month  date        day
# 0  2015-01-01            43      1     1   Thursday
# 1  2015-01-02            52      1     2     Friday
# 2  2015-01-05            72      1     5     Monday
# 3  2015-01-06            33      1     6    Tuesday
# 4  2015-01-07             2      1     7  Wednesday
# 5  2015-01-08            77      1     8   Thursday
# 6  2015-01-09            39      1     9     Friday
# 7  2015-01-12            69      1    12     Monday
# 8  2015-01-13            10      1    13    Tuesday
# 9  2015-01-14            67      1    14  Wednesday
# 10 2015-01-15            51      1    15   Thursday
# 11 2015-01-16            43      1    16     Friday
# 12 2015-01-19            30      1    19     Monday
# 13 2015-01-20            39      1    20    Tuesday
# 14 2015-01-21            20      1    21  Wednesday
# 15 2015-01-22            73      1    22   Thursday
# 16 2015-01-23            53      1    23     Friday
# ...

# %%
# Find the sum of the values in s for every Wednesday
s=create_calendar()
wednes=np.where(s['day'] == 'Wednesday')
wednes_values=s.loc[wednes]
all_wednesday_random_sum=wednes_values["random_index"].sum()
all_wednesday_random_sum
# Out:
# 2729

# %%
#Average For each calendar month
s=create_calendar()
each_month=s.groupby(by= s["month"])
each_months_sum=each_month.random_index
monthly_average=each_months_sum.mean()
np.round(monthly_average,decimals=1)
# Out:
# month
# 1     59.5
# 2     50.8
# 3     56.6
# 4     47.6
# 5     52.0
# 6     60.7
# 7     57.7
# 8     54.5
# 9     40.4
# 10    60.5
# 11    47.6
# 12    50.3
# Name: random_index, dtype: float64

# %%
#For each group of four consecutive calendar months in s, find the date on which thehighest value occurred.
s=create_calendar()
d=s.groupby(s["month"]%4).agg(['max','idxmax'])
d
# Out:
#             Date        random_index        month        date
#              max idxmax          max idxmax   max idxmax  max idxmax
# month
# 0     2015-12-31    260           99     81    12    238   31    172
# 1     2015-09-30    194           99     93     9    173   30     21
# 2     2015-10-30    216           99    125    10    195   30    128
# 3     2015-11-30    237           99    221    11    217   31     63

# %%
#Read the dataset from the below link
import pandas as pd
baby_names=pd.read_csv("https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/US_Baby_Names/US_Baby_Names_right.csv",sep=",")
baby_names.head(20)
# Out:
#     Unnamed: 0     Id       Name  Year Gender State  Count
# 0        11349  11350       Emma  2004      F    AK     62
# 1        11350  11351    Madison  2004      F    AK     48
# 2        11351  11352     Hannah  2004      F    AK     46
# 3        11352  11353      Grace  2004      F    AK     44
# 4        11353  11354      Emily  2004      F    AK     41
# 5        11354  11355    Abigail  2004      F    AK     37
# 6        11355  11356     Olivia  2004      F    AK     33
# 7        11356  11357   Isabella  2004      F    AK     30
# 8        11357  11358     Alyssa  2004      F    AK     29
# 9        11358  11359     Sophia  2004      F    AK     28
# 10       11359  11360     Alexis  2004      F    AK     27
# 11       11360  11361  Elizabeth  2004      F    AK     27
# 12       11361  11362     Hailey  2004      F    AK     27
# 13       11362  11363       Anna  2004      F    AK     26
# 14       11363  11364    Natalie  2004      F    AK     25
# ...

# %%
baby_names.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1016395 entries, 0 to 1016394
# Data columns (total 7 columns):
# Unnamed: 0    1016395 non-null int64
# Id            1016395 non-null int64
# Name          1016395 non-null object
# Year          1016395 non-null int64
# Gender        1016395 non-null object
# State         1016395 non-null object
# Count         1016395 non-null int64
# dtypes: int64(4), object(3)
# memory usage: 54.3+ MB

# %%
#Delete unnamed columns
baby_names.rename({"Unnamed: 0":"A"},axis="columns",inplace=True)
baby_names.drop(["A"],axis=1,inplace=True)

# %%
baby_names.head(5)
# Out:
#       Id     Name  Year Gender State  Count
# 0  11350     Emma  2004      F    AK     62
# 1  11351  Madison  2004      F    AK     48
# 2  11352   Hannah  2004      F    AK     46
# 3  11353    Grace  2004      F    AK     44
# 4  11354    Emily  2004      F    AK     41

# %%
#Show the distribution of male and female
baby_names.head(5)
gender_distribution=baby_names.groupby(by= baby_names["Gender"])["Count"].count()
gender_distribution
# Out:
# Gender
# F    558846
# M    457549
# Name: Count, dtype: int64

# %%
 #Show the top 5 most preferred names
baby_names["Name"].value_counts().head(5)
# Out:
# Riley     1112
# Avery     1080
# Jordan    1073
# Peyton    1064
# Hayden    1049
# Name: Name, dtype: int64

# %%
#What is the median name occurrence in the dataset
index=baby_names["Count"].median()
baby_names.loc[index]
# Out:
# Id            11361
# Name      Elizabeth
# Year           2004
# Gender            F
# State            AK
# Count            27
# Name: 11, dtype: object

# %%
#Distribution of male and female born count by states
born_count=baby_names.groupby(["State","Gender"])["Count"].count()
born_count.head(10)
# Out:
# State  Gender
# AK     F          2404
#        M          2587
# AL     F          9878
#        M          8419
# AR     F          7171
#        M          6475
# AZ     F         14518
#        M         10820
# CA     F         45144
#        M         31637
# Name: Count, dtype: int64

# %%
#program which accepts a list named : randomList = ['a', 0, 2],Using exception handling 
randomlist=["c",0,2]
try:
    for i in randomlist:
        if str(i).isalpha() == True:
            print("The entry is "+i)
            print("Oops!<class'ValueError'> occured")
            break
            
        elif int(i) == 0:
            print("The entry is ",i)
            print("Oops!<class'Zero Division Error'> occured")
            break
        elif int(i) != 0:
            print("The entry is ",i)
            print("Reciprocal of "+ str(i) +  "is",1/i)
            break
        else:
            print("invalid")

   
finally:
    print("Next entry")
# Out:
# The entry is c
# Oops!<class'ValueError'> occured
# Next entry

# %%
# program to illustrate Array out of  Bounds Exception
inarray=[23,45,67,89,12]
maxx=0
try:
    for i in inarray:
    
        if i > i+1:
            maxx=inarray[i]
        elif i < i+1:
            maxx=inarray[i+1]
except :
    print("Array out of Bounds Exception")
print(maxx)
# Out:
# Array out of Bounds Exception
# 0

# %%
#python module script that contains fib2() method to calculate the Fibonacci series
#def fib2(number):
#    a=0
#    b=1
#    for i in range(0,number+1):
#        a,b=b,a+b
#        print(a)
#saved as fibo.py

# %%
import fibo
f=fib2(5)
print(f)
# Out:
# 1
# 1
# 2
# 3
# 5
# 8
# None

# %%
#python module script that contains ispalindrome() method to calculate the input string as palindrome
#def isp(a_string):
#    if a[::-1] == a:
#        return(" Strings are palindrome")
#    else:
#        return("Strings are not palindrome")
#saved as palin.py

# %%
import palin
print(palin.isp("madam"))
# Out:
#  Strings are palindrome

# %%
"""Write a program in Python with one class called Cipher. Within the constructor of this
class, ask user for a string and store it. Use a static variable, key to store a randomly
generated integer between 1 and 50 inclusive. Implement two methods, encrypt and
decrypt within this class. Encrypt generates and prints a cipher text using the user-entered
string and the key and ecrypt generates decrypted string from ciphertext. The cipher only
encrypts alpha and numeric (A-Z, a-z, 0-9). All Symbols, such as - , ; %, remain unencrypted.
The cipher text can have special characters. Use generator expression to filter out alpha and
numeric characters of the input string and to generate cipher text. Create an instance of this
class, encrypt and decrypt back the user entered string."""

# %%
import numpy as np

class Cypher:

    def __init__(self, text):
        print ("Original Text : " + str(text))
        self.text = text
        self.key = np.random.randint(low=1,high=5,size=len(text))
        self.encrypted_text = ""
        self.decrypted_text = ""

    def generate_cypher(self, string):
        for char in string:
            if char.isalnum():
                yield char
            else:
                yield None

    def encrypt(self):
        self.generator_fn = self.generate_cypher(self.text)
        for it in range(0, len(self.text)):
            alnum = next(self.generator_fn)
            if alnum is None:
                self.encrypted_text = self.encrypted_text + self.text[it]
            else:
                self.encrypted_text = self.encrypted_text + chr(ord(alnum) - self.key[it])
        print ("Encrypted Text: " + self.encrypted_text)

    def decrypt(self):
        self.generator_fn = self.generate_cypher(self.encrypted_text)
        for it in range(0, len(self.encrypted_text)):
            alnum = next(self.generator_fn)
            if alnum is None:
                self.decrypted_text = self.decrypted_text + self.encrypted_text[it]
            else:
                self.decrypted_text = self.decrypted_text + chr(ord(alnum) + self.key[it])
        print ("Decrypted Text: " + self.decrypted_text)



inp_text = "in&put"
crypto = Cypher(inp_text)
crypto.encrypt()
crypto.decrypt()
# Out:
# Original Text : in&put
# Encrypted Text: fm&ltr
# Decrypted Text: in&put

# %%
#Get Data from the following link:
#http://files.grouplens.org/datasets/movielens/ml-20m.zip


#Read the dataset using pandas.
import pandas as pd
tag_data=pd.read_csv(r"C:\Users\Chidi\Documents\tags.csv",sep=",")
tag_data.head(10)
# Out:
#    userId  movieId               tag   timestamp
# 0      18     4141       Mark Waters  1240597180
# 1      65      208         dark hero  1368150078
# 2      65      353         dark hero  1368150079
# 3      65      521     noir thriller  1368149983
# 4      65      592         dark hero  1368150078
# 5      65      668         bollywood  1368149876
# 6      65      898  screwball comedy  1368150160
# 7      65     1248     noir thriller  1368149983
# 8      65     1391              mars  1368150055
# 9      65     1617          neo-noir  1368150217

# %%
#Extract the first row from tags and print its type.
type(tag_data.head(1))
# Out:
# pandas.core.frame.DataFrame

# %%
#Extract row 0, 11, 2000 from tags DataFrame.
tag_data.iloc[[0,11,2000]]
# Out:
#       userId  movieId                tag   timestamp
# 0         18     4141        Mark Waters  1240597180
# 11        65     1783      noir thriller  1368149983
# 2000     910    68554  conspiracy theory  1368043943

# %%
#Print index, columns of the DataFrame.
tag_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 465564 entries, 0 to 465563
# Data columns (total 4 columns):
# userId       465564 non-null int64
# movieId      465564 non-null int64
# tag          465548 non-null object
# timestamp    465564 non-null int64
# dtypes: int64(3), object(1)
# memory usage: 14.2+ MB

# %%
#Calculate descriptive statistics for the 'ratings' column of the ratings DataFrame. Verify using describe().
ratings_data=pd.read_csv(r"C:\Users\Chidi\Documents\ratings.csv",sep=",")
ratings_data.head(5)
# Out:
#    userId  movieId  rating   timestamp
# 0       1        2     3.5  1112486027
# 1       1       29     3.5  1112484676
# 2       1       32     3.5  1112484819
# 3       1       47     3.5  1112484727
# 4       1       50     3.5  1112484580

# %%
#Calculate descriptive statistics for the 'ratings' column of the ratings DataFrame. Verify using describe().
ratings_data["rating"].mean()
ratings_data.describe()
# Out:
#              userId       movieId        rating     timestamp
# count  2.000026e+07  2.000026e+07  2.000026e+07  2.000026e+07
# mean   6.904587e+04  9.041567e+03  3.525529e+00  1.100918e+09
# std    4.003863e+04  1.978948e+04  1.051989e+00  1.621694e+08
# min    1.000000e+00  1.000000e+00  5.000000e-01  7.896520e+08
# 25%    3.439500e+04  9.020000e+02  3.000000e+00  9.667977e+08
# 50%    6.914100e+04  2.167000e+03  3.500000e+00  1.103556e+09
# 75%    1.036370e+05  4.770000e+03  4.000000e+00  1.225642e+09
# max    1.384930e+05  1.312620e+05  5.000000e+00  1.427784e+09

# %%
#Filter out ratings with rating > 5
import numpy as np
rating_index=np.where( ratings_data["rating"] >= 5)
s=ratings_data.loc[rating_index]
s.head(5)
# Out:
#      userId  movieId  rating   timestamp
# 131       1     4993     5.0  1112484682
# 142       1     5952     5.0  1112484619
# 158       1     7153     5.0  1112484633
# 170       1     8507     5.0  1094786027
# 176       2       62     5.0   974820598

# %%
#Find how many null values, missing values are present. Deal with them. Print out how many rows have been modified.
ratings_data.isnull().count()
# Out:
# userId       20000263
# movieId      20000263
# rating       20000263
# timestamp    20000263
# dtype: int64

# %%
ratings_data.fillna(value=0)
ratings_data.isnull().count()
# Out:
# userId       20000263
# movieId      20000263
# rating       20000263
# timestamp    20000263
# dtype: int64

# %%
#Filter out movies from the movies DataFrame that are of type 'Animation'.
movies_data=pd.read_csv(r"C:\Users\Chidi\Documents\movies.csv",sep=",")
movies_data.head(5)
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
#Filter out movies from the movies DataFrame that are of type 'Animation'.
gen=np.where( movies_data["genres"] =='Animation' )
movies_data.loc[gen].head(5)
# Out:
#       movieId                                    title     genres
# 2503     2588                         Cloudland (1998)  Animation
# 4906     5002                     Fritz the Cat (1972)  Animation
# 4907     5003  Nine Lives of Fritz the Cat, The (1974)  Animation
# 9455    27738          Cathedral, The (Katedra) (2002)  Animation
# 9989    32840                           Vincent (1982)  Animation

# %%
#Find the average rating of movies.
merg=pd.merge(movies_data,ratings_data,how='inner',on='movieId')
merg["rating"].mean()
# Out:
# 3.5255285642993797

# %%
#Perform an inner join of movies and tags based on movieId.
mergee=pd.merge(movies_data,tag_data,how='inner',on='movieId')
mergee.head(5)
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId                                     tag   timestamp
# 0    1644                                 Watched  1417736680
# 1    1741                      computer animation  1183903155
# 2    1741                 Disney animated feature  1183933307
# 3    1741                         Pixar animation  1183934770
# 4    1741  T̩a Leoni does not star in this movie  1245093573

# %%
# Print out the 5 movies that belong to the Comedy genre and have rating greater than 4.
index=np.where((merg["genres"] == 'Comedy')  &   (merg["rating"] > 4))
merg.loc[index].head(5)
# Out:
#        movieId                               title  genres  userId  rating  \
# 87435        5  Father of the Bride Part II (1995)  Comedy     117     5.0
# 87437        5  Father of the Bride Part II (1995)  Comedy     127     5.0
# 87455        5  Father of the Bride Part II (1995)  Comedy     350     5.0
# 87460        5  Father of the Bride Part II (1995)  Comedy     390     5.0
# 87462        5  Father of the Bride Part II (1995)  Comedy     401     5.0
#
#         timestamp
# 87435   861553146
# 87437   847127740
# 87455  1360209812
# 87460   836139583
# 87462   847049988

# %%
#Split 'genres' into multiple columns.
a=merg["genres"].str.rsplit(pat="|",expand=True)
a.head(5)
# Out:
#            0          1         2       3        4     5     6     7     8  \
# 0  Adventure  Animation  Children  Comedy  Fantasy  None  None  None  None
# 1  Adventure  Animation  Children  Comedy  Fantasy  None  None  None  None
# 2  Adventure  Animation  Children  Comedy  Fantasy  None  None  None  None
# 3  Adventure  Animation  Children  Comedy  Fantasy  None  None  None  None
# 4  Adventure  Animation  Children  Comedy  Fantasy  None  None  None  None
#
#       9
# 0  None
# 1  None
# 2  None
# 3  None
# 4  None

# %%
#Extract year from title
merg["year"]=merg["title"].str.extract('(\d{4})')
merg.head(2)
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId  rating  timestamp  year
# 0       3     4.0  944919407  1995
# 1       6     5.0  858275452  1995

# %%
#Select rows based on timestamps later than 2015-02-01
import pandas as pd
new_merg=pd.merge(ratings_data,tag_data,how='inner',on='timestamp')
new_merg["timestamp"]=pd.to_datetime(new_merg['timestamp'], unit='s')
index=np.where( new_merg["timestamp"]  >  '2015-02-01')
new_merg.loc[index].head(5)
# Out:
#     userId_x  movieId_x  rating           timestamp  userId_y  movieId_y  \
# 24       318       5363     2.0 2015-02-24 04:03:09     70201     129009
# 50       692      79139     0.5 2015-02-18 23:58:34     83024     106841
# 51       692      84374     0.5 2015-02-18 23:58:08     83024     115569
# 62       828      54286     4.0 2015-03-12 18:46:02     41273       7160
# 63       828      60069     3.0 2015-03-12 18:45:58     41273       7160
#
#                  tag
# 24  Cory Krueckeberg
# 50  bleak atmosphere
# 51              dark
# 62   Charlize Theron
# 63    mental illness

# %%
#Sort the tags DataFrame based on timestamp.
tag_data["timestamp"]=pd.to_datetime(tag_data["timestamp"],unit='s')
tag_data.sort_values(by="timestamp",ascending="True")
tag_data.head(10)
# Out:
#    userId  movieId               tag           timestamp
# 0      18     4141       Mark Waters 2009-04-24 18:19:40
# 1      65      208         dark hero 2013-05-10 01:41:18
# 2      65      353         dark hero 2013-05-10 01:41:19
# 3      65      521     noir thriller 2013-05-10 01:39:43
# 4      65      592         dark hero 2013-05-10 01:41:18
# 5      65      668         bollywood 2013-05-10 01:37:56
# 6      65      898  screwball comedy 2013-05-10 01:42:40
# 7      65     1248     noir thriller 2013-05-10 01:39:43
# 8      65     1391              mars 2013-05-10 01:40:55
# 9      65     1617          neo-noir 2013-05-10 01:43:37

# %%
#Matplotlib:This assignment is for visualization using matplotlib:data to use:

# %%
url=r"https://raw.githubusercontent.com/Geoyi/Cleaning-Titanic-Data/master/titanic_original.csv"
titanic = pd.read_csv(url,sep=',')
titanic.head(10)
# Out:
#    pclass  survived                                             name     sex  \
# 0     1.0       1.0                    Allen, Miss. Elisabeth Walton  female
# 1     1.0       1.0                   Allison, Master. Hudson Trevor    male
# 2     1.0       0.0                     Allison, Miss. Helen Loraine  female
# 3     1.0       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 5     1.0       1.0                              Anderson, Mr. Harry    male
# 6     1.0       1.0                Andrews, Miss. Kornelia Theodosia  female
# 7     1.0       0.0                           Andrews, Mr. Thomas Jr    male
# 8     1.0       1.0    Appleton, Mrs. Edward Dale (Charlotte Lamson)  female
# 9     1.0       0.0                          Artagaveytia, Mr. Ramon    male
#
#        age  sibsp  parch    ticket      fare    cabin embarked boat   body  \
# ...

# %%
#Create a pie chart presenting the male/female proportion

import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
axis='equal'
gender=titanic["survived"].groupby( by =titanic["sex"]).sum()
plt.pie(gender,labels=gender.index)
plt.show()

# %%
#Create a scatterplot with the Fare paid and the Age
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
fig=plt.figure(figsize=(17,6))
plt.scatter(titanic.age,titanic.fare,marker='s',c='g',edgecolors='y')
plt.xlabel("Age")
plt.ylabel("Fare paid")
plt.title("scatterplot with the Fare paid and the Age")
plt.show()

# %%
#   Data Cleaning
import pandas as pd
import numpy as np
airplane_data = pd.DataFrame({'From_To': ['LoNDon_paris', 'MAdrid_miLAN', 'londON_StockhOlm',

'Budapest_PaRis', 'Brussels_londOn'],
'FlightNumber': [10045, np.nan, 10065, np.nan, 10085],

'RecentDelays': [[23, 47], [], [24, 43, 87], [13], [67, 32]],
'Airline': ['KLM(!)', '<Air France> (12)', '(British Airways. )',
'12. Air France', '"Swiss Air"']})

# %%
airplane_data
# Out:
#             From_To  FlightNumber  RecentDelays              Airline
# 0      LoNDon_paris       10045.0      [23, 47]               KLM(!)
# 1      MAdrid_miLAN           NaN            []    <Air France> (12)
# 2  londON_StockhOlm       10065.0  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis           NaN          [13]       12. Air France
# 4   Brussels_londOn       10085.0      [67, 32]          "Swiss Air"

# %%
#Some values in the the FlightNumber column are missing. These numbers are meant to
#increase by 10 with each row so 10055 and 10075 need to be put in place. Fill in these missing
#numbers and make the column an integer column (instead of a float column).
import numpy as np
airplane_data["FlightNumber"].isnull()
airplane_data.fillna(0,inplace=True)
airplane_data.ix[1,'FlightNumber']=10055.0
airplane_data.ix[3,'FlightNumber']=10075.0
my_flight_data=airplane_data.copy()
my_flight_data['FlightNumber'].astype(int)
m_data=airplane_data.copy()

# %%
#The From_To column would be better as two separate columns! Split each string on the
#underscore delimiter _ to give a new temporary DataFrame with the correct values. Assign the
#correct column names to this temporary DataFrame.
new_columns=pd.DataFrame()
new_columns[['From','To']]=airplane_data["From_To"].str.rsplit(pat='_',expand=True)
new_columns
# Out:
#        From         To
# 0    LoNDon      paris
# 1    MAdrid      miLAN
# 2    londON  StockhOlm
# 3  Budapest      PaRis
# 4  Brussels     londOn

# %%
#Notice how the capitalisation of the city names is all mixed up in this temporary DataFrame.
#Standardise the strings so that only the first letter is uppercase (e.g. "londON" should become"London".)
new_columns["From"]=new_columns["From"].str.capitalize()
new_columns["To"]=new_columns["To"].str.capitalize()
new_columns
# Out:
#        From         To
# 0    London      Paris
# 1    Madrid      Milan
# 2    London  Stockholm
# 3  Budapest      Paris
# 4  Brussels     London

# %%
#Delete the From_To column from df and attach the temporary DataFrame from the previous questions.

#airplane_data=airplane_data.drop(columns='From_To')
airplane_data["FlightNumber"]=airplane_data.FlightNumber.astype(int)
airplane_data["From_city"]=new_columns["From"]
airplane_data["To_city"]=new_columns["To"]
airplane_data
# Out:
#             From_To  FlightNumber  RecentDelays              Airline  \
# 0      LoNDon_paris         10045      [23, 47]               KLM(!)
# 1      MAdrid_miLAN         10055            []    <Air France> (12)
# 2  londON_StockhOlm         10065  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis         10075          [13]       12. Air France
# 4   Brussels_londOn         10085      [67, 32]          "Swiss Air"
#
#   From_city    To_city
# 0    London      Paris
# 1    Madrid      Milan
# 2    London  Stockholm
# 3  Budapest      Paris
# 4  Brussels     London

# %%
#Handling Recentdelays column
s['delay1']=[[s.ix[0][0],0,s.ix[2][0],s.ix[3][0],s.ix[4][0]]]
s['delay2']=[[s.ix[0][1],0,s.ix[2][1],0,s.ix[4][1]]]
s['delay3']=[[0,0,s.ix[2][2],0]]
my_flight_data['delay1']=(s.delay1).apply(pd.Series).T
my_flight_data['delay2']=(s.delay2).apply(pd.Series).T
my_flight_data['delay3']=(s.delay3).apply(pd.Series).T

# %%
my_flight_data.fillna(0,inplace=True)
my_flight_data.rename({'RecentDelays' : 'Delays'},axis=1,inplace=True)

my_flight_data
# Out:
#             From_To  FlightNumber        Delays              Airline  delay1  \
# 0      LoNDon_paris       10045.0      [23, 47]               KLM(!)      23
# 1      MAdrid_miLAN       10055.0            []    <Air France> (12)       0
# 2  londON_StockhOlm       10065.0  [24, 43, 87]  (British Airways. )      24
# 3    Budapest_PaRis       10075.0          [13]       12. Air France      13
# 4   Brussels_londOn       10085.0      [67, 32]          "Swiss Air"      67
#
#    delay2  delay3
# 0      47     0.0
# 1       0     0.0
# 2      43    87.0
# 3       0     0.0
# 4      32     0.0
